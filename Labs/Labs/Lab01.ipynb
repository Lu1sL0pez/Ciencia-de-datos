# %%
#Validando credenciales
key = '10741d5b02884b41a06cd2debb8baa7e'
endpoint = 'https://lab01-cv.cognitiveservices.azure.com/'

# %%
# %pip install azure.cognitiveservices.vision.computervision
# Out:
# ...
#      ---------------------------------------- 85.4/85.4 KB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 178.6/178.6 KB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 160.2/160.2 KB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.7/41.7 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 62.8/62.8 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 61.2/61.2 KB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 139.0/139.0 KB 8.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 151.5/151.5 KB 9.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'd:\Descargas\Programas\Python\python.exe -m pip install --upgrade pip' command.

# %%
#Conectando con azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
#Image  
import Vision
import os
# %matplotlib inline

#obteniendo imagen
image_path = '/Contenido Programación/Python/Labs/Images/Im01.jpg'
image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description)

Vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['text', 'person', 'store', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000206FFD5A530>], 'request_id': '1a533bfa-36ab-49d8-ac7a-ba70a3a9fe52', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000206FFD58F10>, 'model_version': '2021-05-01'}

# %%
image_path = '/Contenido Programación/Python/Labs/Images/Im02.png'
image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)

Vision.show_image_caption(image_path, description)

# %%
image_path = '/Contenido Programación/Python/Labs/Images/Im01.jpg'
features = ['Description', 'Tags', 'Objects', 'Adult', 'Faces']
image_stream = open(image_path, "rb")
analysis = client.analyze_image_in_stream(image_stream, visual_features = features)

Vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# ## Face Api

# %%
#Instancia de face api

# !pip install azure-cognitiveservices-vision-face
# Out:
# ...
#      -------------------------------------- 67.7/67.7 kB 736.1 kB/s eta 0:00:00
# ...

# %%
#Credenciales
key = 'd7b25f83aaa74315a5fbc3c8e6ab56d6'
endpoint = 'https://face-lab01.cognitiveservices.azure.com/'

# %%
#Conectando con azure
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import {}faces
import os
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Contenido Programación\Python\Labs\Labs\Lab01.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Contenido%20Programaci%C3%B3n/Python/Labs/Labs/Lab01.ipynb#ch0000011?line=0'>1</a> import faces
#       <a href='vscode-notebook-cell:/d%3A/Contenido%20Programaci%C3%B3n/Python/Labs/Labs/Lab01.ipynb#ch0000011?line=1'>2</a> import os
#       <a href='vscode-notebook-cell:/d%3A/Contenido%20Programaci%C3%B3n/Python/Labs/Labs/Lab01.ipynb#ch0000011?line=2'>3</a> get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'faces'
